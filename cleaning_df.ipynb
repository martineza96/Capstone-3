# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/middletown_menu_df.csv')

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
just_menu = df[['restaurant_name','menus']]

# %%
just_menu.drop_duplicates('restaurant_name',inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
just_menu.set_index('restaurant_name',inplace=True)

# %%
just_menu
# Out:
#                                                                                              menus
# restaurant_name
# Quiznos Sub                                      [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Starbucks Coffee                                 [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Perkins Restaurant & Bakery                      [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Ruby Tuesdays                                    [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Panera Bread                                     [{'menu_name': '', 'menu_sections': [{'section...
# Red Lobster                                      [{'menu_name': 'Prix Fixe', 'menu_sections': [...
# Dunkin'                                          [{'menu_name': '', 'menu_sections': [{'section...
# Dunkin' Donuts                                   [{'menu_name': 'Main', 'menu_sections': [{'sec...
# ...

# %%
l = eval(just_menu.iloc[0]['menus'])

# %%
test_d = {}

for i in l:
    for j in i['menu_sections']:
        for a in j['menu_items']:
            test_d[a['name']] = a['description']

# %%
test_d
# Out:
# {'Sub Sliders (Pick 2)': 'Meatball | Smoky Chipotle Turkey | Turkey Club | Beef, Bacon & Cheddar | BLT Classic',
#  'Grilled Flatbreads (Small)': 'Little Italy | Basil Pesto Chicken | Greek Chicken | Chicken Bacon Ranch | Sonoma Turkey',
#  'Fresh Salads (Small)': 'Harvest Chicken | Cobb | Honey Mustard Chicken | Peppercorn Caesar with Chicken | Mediterranean Chicken',
#  'Savory Soups (Small)': 'Broccoli Cheese | Chicken Noodle | Chili',
#  'Broccoli Cheese ': '',
#  'Chicken Noodle ': '',
#  'Chili': '',
#  'Harvest Chicken': 'Honey-dijon chicken salad, granny smith apples, grapes, dried cranberries, cucumbers, tomatoes, pumpkin seeds, acai vinaigrette dressing.',
#  'Honey Mustard Chicken': 'All-natural chicken, smoky bacon, all-natural cheddar, tomatoes, honey mustard dressing.',
#  'Cobb': 'All-natural chicken, smoky bacon, hard-boiled egg, tomatoes, blue cheese crumbles, buttermilk ranch dressing.',
# ...

# %%
menu_selection = pd.DataFrame(l[0])

# %%
items_df = pd.DataFrame(menu_selection['menu_sections'][0])

# %%
items_df
# Out:
#     section_name                                        description  \
# 0  Choose 2 Menu  The perfect way to have the tastes you want. C...
# 1  Choose 2 Menu  The perfect way to have the tastes you want. C...
# 2  Choose 2 Menu  The perfect way to have the tastes you want. C...
# 3  Choose 2 Menu  The perfect way to have the tastes you want. C...
#
#                                           menu_items
# 0  {'name': 'Sub Sliders (Pick 2)', 'description'...
# 1  {'name': 'Grilled Flatbreads (Small)', 'descri...
# 2  {'name': 'Fresh Salads (Small)', 'description'...
# 3  {'name': 'Savory Soups (Small)', 'description'...

# %%
item_1 = pd.DataFrame(items_df['menu_items'][2])

# %%
item_1
# Out:
#                    name                                        description  \
# 0  Fresh Salads (Small)  Harvest Chicken | Cobb | Honey Mustard Chicken...
#
#                                              pricing  price
# 0  {'price': 0, 'currency': 'USD', 'priceString':...      0

# %%
list(item_1['description'])
# Out:
# ['Little Italy | Basil Pesto Chicken | Greek Chicken | Chicken Bacon Ranch | Sonoma Turkey']

# %%
just_menu
# Out:
#                                                                                              menus
# restaurant_name
# Quiznos Sub                                      [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Starbucks Coffee                                 [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Perkins Restaurant & Bakery                      [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Ruby Tuesdays                                    [{'menu_name': 'Main', 'menu_sections': [{'sec...
# Panera Bread                                     [{'menu_name': '', 'menu_sections': [{'section...
# Red Lobster                                      [{'menu_name': 'Prix Fixe', 'menu_sections': [...
# Dunkin'                                          [{'menu_name': '', 'menu_sections': [{'section...
# Dunkin' Donuts                                   [{'menu_name': 'Main', 'menu_sections': [{'sec...
# ...
